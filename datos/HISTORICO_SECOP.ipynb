# %% [markdown]
# # Extraer la informacion
#
# Se tiene como objetivo el crear el historico de los datos los cuales seran llevados al GitHub en formato .parquet

# %%
# !pip install sodapy
# !pip install requests 
# !pip install pyarrow

# %%
import pandas as pd  
# Conexión a la API REST (SODA API)
import requests  
# Cliente oficial de Socrata 
from sodapy import Socrata  
# Manejo de archivos y sistema
import os

# %%
dataset_id = "p6dx-8zbt"
url = f"https://www.datos.gov.co/resource/{dataset_id}.json"

# Contar el TOTAL de registros
params = {"$select": "count(*)"}
res = requests.get(url, params=params)
total_registros = int(res.json()[0]['count'])
print(f" TOTAL de registros en la base: {total_registros:,}")

# === 3. Consultar metadatos para saber cuántas variables tiene ===
meta_url = f"https://www.datos.gov.co/api/views/{dataset_id}.json"
meta_res = requests.get(meta_url).json()

# Extraer columnas declaradas en el metadata
vars_info = pd.DataFrame([{
    "Nombre": col['name'],
    "Campo (API)": col['fieldName'],
    "Tipo (API)": col['dataTypeName']
} for col in meta_res['columns']])

total_variables = len(vars_info)
print(f" TOTAL de variables en la base: {total_variables}")

# Vista previa de las variables
print("\n Variables disponibles:")
print(vars_info)
# Out:
# ✅ TOTAL de registros en la base: 7,676,998
# ✅ TOTAL de variables en la base: 59
#
# 📌 Variables disponibles:
#                                                Nombre  \
# 0                                             Entidad
# 1                                         Nit Entidad
# 2                                Departamento Entidad
# 3                                      Ciudad Entidad
# 4                                        OrdenEntidad
# 5                                Entidad Centralizada
# 6                                      ID del Proceso
# 7                              Referencia del Proceso
# 8                                                 PCI
# 9                                   ID del Portafolio
# 10                           Nombre del Procedimiento
# 11                      Descripción del Procedimiento
# 12                                               Fase
# 13                   Fecha de Publicacion del Proceso
# 14                        Fecha de Ultima Publicación
# 15  Fecha de Publicacion (Fase Planeacion Precalif...
# 16  Fecha de Publicacion (Fase Seleccion Precalifi...
# 17    Fecha de Publicacion (Manifestacion de Interes)
# 18               Fecha de Publicacion (Fase Borrador)
# 19              Fecha de Publicacion (Fase Seleccion)
# 20                                        Precio Base
# 21                          Modalidad de Contratacion
# 22            Justificación Modalidad de Contratación
# 23                                           Duracion
# 24                                 Unidad de Duracion
# 25                   Fecha de Recepcion de Respuestas
# 26                     Fecha de Apertura de Respuesta
# 27                         Fecha de Apertura Efectiva
# 28                Ciudad de la Unidad de Contratación
# 29                Nombre de la Unidad de Contratación
# 30                              Proveedores Invitados
# 31                 Proveedores con Invitacion Directa
# 32                  Visualizaciones del Procedimiento
# 33               Proveedores que Manifestaron Interes
# 34                        Respuestas al Procedimiento
# 35                                Respuestas Externas
# 36                     Conteo de Respuestas a Ofertas
# 37                  Proveedores Unicos con Respuestas
# 38                                    Numero de Lotes
# 39                           Estado del Procedimiento
# 40                        ID Estado del Procedimiento
# 41                                         Adjudicado
# 42                                    ID Adjudicacion
# 43                                    CodigoProveedor
# 44                             Departamento Proveedor
# 45                                   Ciudad Proveedor
# 46                                 Fecha Adjudicacion
# 47                           Valor Total Adjudicacion
# 48                             Nombre del Adjudicador
# 49                    Nombre del Proveedor Adjudicado
# 50                       NIT del Proveedor Adjudicado
# 51                      Codigo Principal de Categoria
# 52                     Estado de Apertura del Proceso
# 53                                   Tipo de Contrato
# 54                                Subtipo de Contrato
# 55                             Categorias Adicionales
# 56                                         URLProceso
# 57                                     Codigo Entidad
# 58                                     Estado Resumen
#
#                        Campo (API)     Tipo (API)
# 0                          entidad           text
# 1                      nit_entidad           text
# 2             departamento_entidad           text
# 3                   ciudad_entidad           text
# 4                     ordenentidad           text
# 5                       codigo_pci           text
# 6                   id_del_proceso           text
# 7           referencia_del_proceso           text
# 8                              ppi           text
# 9                id_del_portafolio           text
# 10        nombre_del_procedimiento           text
# 11   descripci_n_del_procedimiento           text
# 12                            fase           text
# 13        fecha_de_publicacion_del  calendar_date
# 14       fecha_de_ultima_publicaci  calendar_date
# 15       fecha_de_publicacion_fase  calendar_date
# 16     fecha_de_publicacion_fase_1  calendar_date
# 17            fecha_de_publicacion  calendar_date
# 18     fecha_de_publicacion_fase_2  calendar_date
# 19     fecha_de_publicacion_fase_3  calendar_date
# 20                     precio_base         number
# 21       modalidad_de_contratacion           text
# 22      justificaci_n_modalidad_de           text
# 23                        duracion         number
# 24              unidad_de_duracion           text
# 25           fecha_de_recepcion_de  calendar_date
# 26  fecha_de_apertura_de_respuesta  calendar_date
# 27      fecha_de_apertura_efectiva  calendar_date
# 28          ciudad_de_la_unidad_de           text
# 29          nombre_de_la_unidad_de           text
# 30           proveedores_invitados         number
# 31      proveedores_con_invitacion         number
# 32             visualizaciones_del         number
# 33    proveedores_que_manifestaron         number
# 34     respuestas_al_procedimiento         number
# 35             respuestas_externas         number
# 36  conteo_de_respuestas_a_ofertas         number
# 37          proveedores_unicos_con         number
# 38                 numero_de_lotes         number
# 39        estado_del_procedimiento           text
# 40     id_estado_del_procedimiento         number
# 41                      adjudicado           text
# 42                 id_adjudicacion           text
# 43                 codigoproveedor           text
# 44          departamento_proveedor           text
# 45                ciudad_proveedor           text
# 46              fecha_adjudicacion  calendar_date
# 47        valor_total_adjudicacion         number
# 48          nombre_del_adjudicador           text
# 49            nombre_del_proveedor           text
# 50    nit_del_proveedor_adjudicado           text
# 51   codigo_principal_de_categoria           text
# 52  estado_de_apertura_del_proceso           text
# 53                tipo_de_contrato           text
# 54             subtipo_de_contrato           text
# 55          categorias_adicionales           text
# 56                      urlproceso            url
# 57                  codigo_entidad         number
# 58                  estado_resumen           text

# %%
# ejemplo: 50,000 registros, ordenados por fecha
params = {
    "$limit": 50000,
    "$offset": 0,
    "$order": "fecha_de_publicacion_del ASC"   # menor a mayor
}
res = requests.get(url, params=params)
df = pd.DataFrame(res.json())

# Convertir SOLO la variable "Fecha de Publicacion del Proceso"
fecha_col = "fecha_de_publicacion_del"
if fecha_col in df.columns:
    df[fecha_col] = pd.to_datetime(df[fecha_col], errors="coerce")

print(f"\n📊 Primer lote descargado")
print(f"   - Registros en el lote: {len(df):,}")
print(f"   - Variables en el lote: {df.shape[1]}")

print("\n Primeros 5 registros (con fecha ya convertida):")
print(df.head())
# Out:
# 📊 Primer lote descargado
#    - Registros en el lote: 50,000
#    - Variables en el lote: 57
#
# 📌 Primeros 5 registros (con fecha ya convertida):
#                                              entidad nit_entidad  \
# 0  EMPRESA DE ACUEDUCTO Y ALCANTARILLADO DE BOGOT...   899999094
# 1  EMPRESA DE ACUEDUCTO Y ALCANTARILLADO DE BOGOT...   899999094
# 2  EMPRESA DE ACUEDUCTO Y ALCANTARILLADO DE BOGOT...   899999094
# 3  EMPRESA DE ACUEDUCTO Y ALCANTARILLADO DE BOGOT...   899999094
# 4  EMPRESA DE ACUEDUCTO Y ALCANTARILLADO DE BOGOT...   899999094
#
#          departamento_entidad ciudad_entidad ordenentidad       codigo_pci  \
# 0  Distrito Capital de Bogotá         Bogotá  Territorial  Descentralizada
# 1  Distrito Capital de Bogotá         Bogotá  Territorial  Descentralizada
# 2  Distrito Capital de Bogotá         Bogotá  Territorial  Descentralizada
# 3  Distrito Capital de Bogotá         Bogotá  Territorial  Descentralizada
# 4  Distrito Capital de Bogotá         Bogotá  Territorial  Descentralizada
#
#   id_del_proceso referencia_del_proceso        ppi id_del_portafolio  ...  \
# 0    CO1.REQ.501          ISG-0334-2015  700064108      CO1.BDOS.501  ...
# 1    CO1.REQ.601         ICGH-0330-2015  700064108      CO1.BDOS.601  ...
# 2    CO1.REQ.605           IJ-0354-2015  700064108      CO1.BDOS.606  ...
# 3    CO1.REQ.602           IF-0332-2015  700064108      CO1.BDOS.602  ...
# 4    CO1.REQ.701         ICGH-0336-2015  700064108      CO1.BDOS.701  ...
#
#   categorias_adicionales                                         urlproceso  \
# 0            No definido  {'url': 'https://community.secop.gov.co/Public...
# 1            No definido  {'url': 'https://community.secop.gov.co/Public...
# 2            No definido  {'url': 'https://community.secop.gov.co/Public...
# 3            No definido  {'url': 'https://community.secop.gov.co/Public...
# 4            No definido  {'url': 'https://community.secop.gov.co/Public...
#
#   codigo_entidad          estado_resumen fecha_de_publicacion_fase_2  \
# 0      700064108  Presentación de oferta                         NaN
# 1      700064108  Presentación de oferta                         NaN
# 2      700064108  Presentación de oferta                         NaN
# 3      700064108  Presentación de oferta                         NaN
# 4      700064108  Presentación de oferta                         NaN
#
#   fecha_de_recepcion_de fecha_de_apertura_de_respuesta  \
# 0                   NaN                            NaN
# 1                   NaN                            NaN
# 2                   NaN                            NaN
# 3                   NaN                            NaN
# 4                   NaN                            NaN
#
#   fecha_de_apertura_efectiva fecha_adjudicacion fecha_de_publicacion
# 0                        NaN                NaN                  NaN
# 1                        NaN                NaN                  NaN
# 2                        NaN                NaN                  NaN
# 3                        NaN                NaN                  NaN
# 4                        NaN                NaN                  NaN
#
# [5 rows x 57 columns]

# %%
params = {
    "$limit": 100000,
    "$offset": 0,
    "$order": "fecha_de_publicacion_del ASC"
}
print("\nEjemplos de valores en bruto:")
print(df["fecha_de_publicacion_del"].dropna().head(10).tolist())

# Convertir la fecha con formato flexible
df["fecha_de_publicacion_del"] = pd.to_datetime(
    df["fecha_de_publicacion_del"],
    errors="coerce",
    utc=True,               # mantener en UTC si viene con hora
)

# Validar  NA
total_na = df["fecha_de_publicacion_del"].isna().sum()
print(f"\n Total fechas nulas después de conversión: {total_na:,}")

# Guardar en .parquet
ruta = r"C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_1_prueba.parquet"
df.to_parquet(ruta, engine="pyarrow", index=False)
print(f" Lote guardado en: {ruta}")

# para validar
df_parquet = pd.read_parquet(ruta)
print("\n Primeros 5 registros con fecha convertida:")
print(df_parquet[["fecha_de_publicacion_del"]].head())
# Out:
# Ejemplos de valores en bruto:
# [Timestamp('2015-04-16 00:00:00'), Timestamp('2015-04-20 00:00:00'), Timestamp('2015-04-20 00:00:00'), Timestamp('2015-04-20 00:00:00'), Timestamp('2015-04-20 00:00:00'), Timestamp('2015-04-20 00:00:00'), Timestamp('2015-04-20 00:00:00'), Timestamp('2015-04-20 00:00:00'), Timestamp('2015-04-20 00:00:00'), Timestamp('2015-04-20 00:00:00')]
#
# 📊 Total fechas nulas después de conversión: 0
# ✅ Lote guardado en: C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_1_prueba.parquet
#
# Primeros 5 registros con fecha convertida:
#    fecha_de_publicacion_del
# 0 2015-04-16 00:00:00+00:00
# 1 2015-04-20 00:00:00+00:00
# 2 2015-04-20 00:00:00+00:00
# 3 2015-04-20 00:00:00+00:00
# 4 2015-04-20 00:00:00+00:00

# %%
from datetime import datetime, timedelta
ruta_salida = r"C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes"

# fecha mínima y máxima
query = {
    "$select": "min(fecha_de_publicacion_del) as min_fecha, max(fecha_de_publicacion_del) as max_fecha"
}
res = requests.get(url, params=query)
fechas = res.json()[0]

min_fecha = pd.to_datetime(fechas["min_fecha"])
max_fecha = pd.to_datetime(fechas["max_fecha"])

print(f" Rango total: {min_fecha.date()} → {max_fecha.date()}")

# Generar semestres
semestres = []
anio = min_fecha.year
while anio <= max_fecha.year:
    # Primer semestre
    inicio_s1 = datetime(anio, 1, 1)
    fin_s1 = datetime(anio, 6, 30)

    # Segundo semestre
    inicio_s2 = datetime(anio, 7, 1)
    fin_s2 = datetime(anio, 12, 31)

    semestres.append((anio, "S1", inicio_s1, fin_s1))
    semestres.append((anio, "S2", inicio_s2, fin_s2))

    anio += 1

# Ajustar primer y último semestre según rango real
semestres = [
    (a, s, max(inicio, min_fecha), min(fin, max_fecha))
    for a, s, inicio, fin in semestres
    if fin >= min_fecha and inicio <= max_fecha
]

# Descargar y guardar cada semestre
for anio, semestre, inicio, fin in semestres:
    print(f"\n📥 Descargando {anio}_{semestre} ({inicio.date()} → {fin.date()})...")

    params = {
        "$where": f"fecha_de_publicacion_del between '{inicio.date()}' and '{fin.date()}'",
        "$limit": 100000,  # Socrata sigue limitando, toca paginar
        "$offset": 0,
        "$order": "fecha_de_publicacion_del ASC"
    }

    df_total = pd.DataFrame()

    while True:
        res = requests.get(url, params=params)
        datos = res.json()
        if not datos:
            break

        df = pd.DataFrame(datos)

        # === Arreglo de la fecha ===
        if "fecha_de_publicacion_del" in df.columns:
            df["fecha_de_publicacion_del"] = pd.to_datetime(
                df["fecha_de_publicacion_del"], errors="coerce", utc=True
            )

        df_total = pd.concat([df_total, df], ignore_index=True)

        # Avanzar en la paginación
        params["$offset"] += params["$limit"]

    # === Guardar parquet ===
    archivo_out = os.path.join(ruta_salida, f"lote_{anio}_{semestre}.parquet")
    df_total.to_parquet(archivo_out, engine="pyarrow", index=False)
    print(f"   ✅ Guardado {len(df_total):,} registros en {archivo_out}")

print("\n🚀 Descarga completa y archivada por semestres")
# Out:
# 📅 Rango total: 2015-04-16 → 2025-09-08
#
# 📥 Descargando 2015_S1 (2015-04-16 → 2015-06-30)...
#    ✅ Guardado 313 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2015_S1.parquet
#
# 📥 Descargando 2015_S2 (2015-07-01 → 2015-12-31)...
#    ✅ Guardado 2,959 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2015_S2.parquet
#
# 📥 Descargando 2016_S1 (2016-01-01 → 2016-06-30)...
#    ✅ Guardado 3,598 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2016_S1.parquet
#
# 📥 Descargando 2016_S2 (2016-07-01 → 2016-12-31)...
#    ✅ Guardado 6,463 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2016_S2.parquet
#
# 📥 Descargando 2017_S1 (2017-01-01 → 2017-06-30)...
#    ✅ Guardado 15,752 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2017_S1.parquet
#
# 📥 Descargando 2017_S2 (2017-07-01 → 2017-12-31)...
#    ✅ Guardado 31,484 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2017_S2.parquet
#
# 📥 Descargando 2018_S1 (2018-01-01 → 2018-06-30)...
#    ✅ Guardado 115,977 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2018_S1.parquet
#
# 📥 Descargando 2018_S2 (2018-07-01 → 2018-12-31)...
#    ✅ Guardado 118,405 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2018_S2.parquet
#
# 📥 Descargando 2019_S1 (2019-01-01 → 2019-06-30)...
#    ✅ Guardado 170,851 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2019_S1.parquet
#
# 📥 Descargando 2019_S2 (2019-07-01 → 2019-12-31)...
#    ✅ Guardado 55,994 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2019_S2.parquet
#
# 📥 Descargando 2020_S1 (2020-01-01 → 2020-06-30)...
#    ✅ Guardado 243,898 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2020_S1.parquet
#
# 📥 Descargando 2020_S2 (2020-07-01 → 2020-12-31)...
#    ✅ Guardado 240,767 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2020_S2.parquet
#
# 📥 Descargando 2021_S1 (2021-01-01 → 2021-06-30)...
#    ✅ Guardado 384,058 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2021_S1.parquet
#
# 📥 Descargando 2021_S2 (2021-07-01 → 2021-12-31)...
#    ✅ Guardado 336,658 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2021_S2.parquet
#
# 📥 Descargando 2022_S1 (2022-01-01 → 2022-06-30)...
#    ✅ Guardado 492,438 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2022_S1.parquet
#
# 📥 Descargando 2022_S2 (2022-07-01 → 2022-12-31)...
#    ✅ Guardado 634,188 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2022_S2.parquet
#
# 📥 Descargando 2023_S1 (2023-01-01 → 2023-06-30)...
#    ✅ Guardado 973,908 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2023_S1.parquet
#
# 📥 Descargando 2023_S2 (2023-07-01 → 2023-12-31)...
#    ✅ Guardado 645,767 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2023_S2.parquet
#
# 📥 Descargando 2024_S1 (2024-01-01 → 2024-06-30)...
#    ✅ Guardado 865,022 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2024_S1.parquet
#
# 📥 Descargando 2024_S2 (2024-07-01 → 2024-12-31)...
#    ✅ Guardado 859,426 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2024_S2.parquet
#
# 📥 Descargando 2025_S1 (2025-01-01 → 2025-06-30)...
#    ✅ Guardado 1,055,585 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2025_S1.parquet
#
# 📥 Descargando 2025_S2 (2025-07-01 → 2025-09-08)...
#    ✅ Guardado 348,378 registros en C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\lote_2025_S2.parquet
#
# 🚀 Descarga completa y archivada por semestres

# %%
import shutil
origen = "HISTORICO_SECOP.ipynb"
destino = r"C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\HISTORICO_SECOP.ipynb"

shutil.copy(origen, destino)
print(f"✅ Notebook copiado a: {destino}")
# Out:
# ✅ Notebook copiado a: C:\Users\aleja\OneDrive\Escritorio\Consultoria\desarrollo_social_y_economico\Lotes\HISTORICO_SECOP.ipynb
